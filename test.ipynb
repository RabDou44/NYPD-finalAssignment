# %%
# %pip install -e "./Pitmodule"
# Out:
# Obtaining file:///home/adam/NYPD/nypd-finalassignment/Pitmodule
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: Pitmodule
#     Found existing installation: Pitmodule 1.0
#     Uninstalling Pitmodule-1.0:
#       Successfully uninstalled Pitmodule-1.0
#   Running setup.py develop for Pitmodule
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from Pitmodule import *
pit2019 = pitmodule.PitFrame(year=2019)
pit2020 = pitmodule.PitFrame(year=2020)

# %%
# testowanie uproszczenia, zgdonosci formatu oraz getPIT
pit2020 == pit2019 == pitmodule.PitFrame(is_path=False)
tmp = pit2020.get_PIT()
tmp.data.keys()
# Out:
# dict_keys(['Gminy', 'Powiaty', 'Wojewodztwa', 'Metropolia', 'Miasta_Gminy', 'Miasta_Powiaty'])

# %%
# task1 Compare results
t = pit2020.compare(pit2019)
df = t.data["Miasta_Powiaty"]
df[ df["wojewodztwo"] == "mazowieckie"]
# Out:
#                 jst  wojewodztwo powiat naleznosci2020 naleznosci2019  \
# 20        Ostrołęka  mazowieckie      -       14430953       15132261
# 21            Płock  mazowieckie      -       40963925       43155284
# 22            Radom  mazowieckie      -       58062919       60575893
# 23          Siedlce  mazowieckie      -       26017876       26980131
# 24  m. st. Warszawa  mazowieckie      -     1301271209     1339313472
#
#    Roznica(%)
# 20  -0.046345
# 21  -0.050778
# 22  -0.041485
# 23  -0.035665
# 24  -0.028404

# %%
#task2 compare to population
pit2019.data.items()tr
# Out:
# dict_items([('Gminy',       wk  pk  gk gt           jst         wojewodztwo         powiat klDzial  \
# 0     02  01  01  1   BOLESŁAWIEC        dolnośląskie  bolesławiecki     756
# 1     02  01  02  2   BOLESŁAWIEC        dolnośląskie  bolesławiecki     756
# 2     02  01  03  2      GROMADKA        dolnośląskie  bolesławiecki     756
# 3     02  01  04  3  NOWOGRODZIEC        dolnośląskie  bolesławiecki     756
# 4     02  01  05  2    OSIECZNICA        dolnośląskie  bolesławiecki     756
# ...   ..  ..  .. ..           ...                 ...            ...     ...
# 2406  32  18  01  3         DOBRA  zachodniopomorskie        łobeski     756
# 2407  32  18  02  3         ŁOBEZ  zachodniopomorskie        łobeski     756
# 2408  32  18  03  2   RADOWO MAŁE  zachodniopomorskie        łobeski     756
# 2409  32  18  04  3         RESKO  zachodniopomorskie        łobeski     756
# 2410  32  18  05  3     WĘGORZYNO  zachodniopomorskie        łobeski     756
#
# ...

# %%
# testowanie ludosc 
# calculate per population
from population import *
populacje2020 = PopulationFrame()
populacje2020.data["Powiaty"]
# Out:
# Index(['Gminy', 'id', 'ludnosc'], dtype='object')
# Index(['Powiaty', 'id', 'ludnosc'], dtype='object')
# /home/adam/NYPD/nypd-finalassignment/Pitmodule/population.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame.drop(frame.iloc[:,3:lastcol],axis=1,inplace=True)
# /home/adam/NYPD/nypd-finalassignment/Pitmodule/population.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame.drop(["id"],axis =1,inplace=True)
# /home/adam/NYPD/nypd-finalassignment/Pitmodule/population.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
gminy_populacje = populacje2020.data["Gminy"]
gminy_populacje["Gminy"].strcontain()
# Out:
#                  Gminy  ludnosc
# 0        M.Bolesławiec    38486
# 1        G.Bolesławiec    14863
# 2           G.Gromadka     5317
# 3     M-W.Nowogrodziec    15229
# 4       M.Nowogrodziec     4263
# ...                ...      ...
# 3756       M.Węgorzyno     2771
# 3757       G.Węgorzyno     4085
# 3758        M.Koszalin   106235
# 3759        M.Szczecin   398255
# 3760     M.Świnoujście    40948
#
# [3761 rows x 2 columns]

# %%
pop_gminy_2020 = populacje2020.data["Powiaty"]
o
